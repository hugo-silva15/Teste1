# %% [markdown]
# <a href="https://colab.research.google.com/github/hugo-silva15/Teste1/blob/main/_1_Teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Ola, qual seu nome?")
# Out:
# Ola, qual seu nome?
